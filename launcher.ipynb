# %% [markdown]
# # My AiiDA App Launcher
#
# This notebook launches the MVC application defined in the `mvc_template` directory.

# %%
from src.views.view import YAMLView
from src.models.model import Model
from src.controllers.controller import Controller
import ipywidgets as ipw

# 1. Initialize Model
model = Model()

# 2. Initialize View from YAML
view = YAMLView('src/views/yaml_elements/view.yaml')

# 3. Initialize Controller
controller = Controller(model, view)

# 4. Display
display(view)
